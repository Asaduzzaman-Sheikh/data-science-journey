# %% [markdown]
# # Series
# 🎯A one-dimensional array-like object containing a sequnce of values and associated array of data labels, called its index

# %%
import pandas as pd

# %%
obj = pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
# Get the array representation and index object of the Series
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Customize labels - index parameter
obj2 = pd.Series([4,7,-5,3], index = ['d','b','a','c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
# Use labels in the indexing to get the single value or set of values
print(obj2['a'])
# Out:
# -5

# %%
print(obj2['d'])
# Out:
# 4

# %%
print(obj2[['c','a','d']])
# Out:
# c    3
# a   -5
# d    4
# dtype: int64

# %%
# Filtering with a boolean array
obj2[obj2 > 0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
# Scalar multiplication
obj2 * 2
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
import numpy as np
np.exp(obj2)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
# Mapping of indexing values to data values
'b' in obj2
# Out:
# True

# %%
'e' in obj2
# Out:
# False

# %%
# Convert Python dicttionary to Series
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
# Overide the dict keys in the order we want then to appear
states = ['California','Ohio','Oregon','Texas']
obj4 = pd.Series(sdata, index = states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
# Missing or NA values detect
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
# Or
obj4.isnull()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
# Or
obj4.notnull()
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
""" A useful Series feature for many applications is that it automatically
aligns by index label in arithmetic operations."""

obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
# Both the Series object itself and its index have a name attribute

obj4.name = 'population'

# %%
obj4.index.name = 'state'

# %%
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj4.name
# Out:
# 'population'

# %%
obj4.index.name
# Out:
# 'state'

# %% [markdown]
# # DataFrame
# 🎯🎯A DataFrame represents a rectangular table of data and contains an ordered colection of columns, each of which can be a diiferent value type. It has both row and column index

# %%
# Construct a DataFrame from a dict of equal-length lists or NumPy arrays (common)
data = {'state': ['Ohio','Ohio','Ohio','Nevada','Nevada','Nevada'],
        'year': [2000,2001,2002,2001,2002,2003],
        'pop': [1.5, 1.7,3.6,2.4,2.9,3.2]
       }

frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# For learge DataFrames, the head() method selects only the first five rows
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
# We can pass how many rows we want as parameters
frame.head(3)
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7
# 2  Ohio  2002  3.6

# %%
# For learge DataFrames, the tail() method selects only the last five rows
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# We can pass how many rows we want as parameters
frame.tail(3)
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# Manage sequence of columns according to custom order - using columns parameter
pd.DataFrame(data, columns = ['year','state','pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
# If we pass a column that isn't contained in the dict, it will appear with missing values
frame2 = pd.DataFrame(data, columns = ['year','state','pop','debt'], index = ['one','two','three','four','five','six'])

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
# Columns in the DataFrame
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
# Shape of the DataFrame
frame2.shape
# Out:
# (6, 4)

# %%
# Information about the DataFrame
frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, one to six
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6 non-null      int64
#  1   state   6 non-null      object
#  2   pop     6 non-null      float64
#  3   debt    0 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 240.0+ bytes

# %%
# Statistical summary
frame2.describe()
# Out:
#               year       pop
# count     6.000000  6.000000
# mean   2001.500000  2.550000
# std       1.048809  0.836062
# min    2000.000000  1.500000
# 25%    2001.000000  1.875000
# 50%    2001.500000  2.650000
# 75%    2002.000000  3.125000
# max    2003.000000  3.600000

# %%
# Retrieved a column as a series - dict-like notation
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
# Accessing like object atribute
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
# Rows can also be retrieved by position or name with the special loc attribute
frame2.loc['one']
# Out:
# year     2000
# state    Ohio
# pop       1.5
# debt      NaN
# Name: one, dtype: object

# %%
# Columns can be modified by assignment
frame2['debt'] = 16.5

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Nevada  3.2  16.5

# %%
""" When assigning lists or assarys to a column, the values length must match the length of the DataFrame."""
frame2['debt'] = np.arange(6.)

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   0.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   2.0
# four   2001  Nevada  2.4   3.0
# five   2002  Nevada  2.9   4.0
# six    2003  Nevada  3.2   5.0

# %%
# Assign valus to specific rows - using Series
values = pd.Series([-1.2,-1.5,-1.7], index = ['two','four','five'])

# %%
# If you assign a Series, its labels will be realigned exactly to the DataFrame's index. Inserting missing values in any holes
frame2['debt'] = values

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
# Creatin a new column
frame2['eastern'] = frame2.state == 'Ohio'

# %%
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
# Delete method can be used to remove column
del frame2['eastern']

# %%
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
# DataFrame from dict of dicts
pop = {'Nevada':{2001:2.4, 2002:2.9}, 'Ohio':{2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %%
# If the nested dict is passed to the DataFrame, pandas will interpret the outer dict kes as the columns and the inner keys as the row indices
frame3 = pd.DataFrame(pop)

# %%
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
# DataFrame can be transposed like NumPy array
frame3.T
# Out:
#         2001  2002  2000
# Nevada   2.4   2.9   NaN
# Ohio     1.7   3.6   1.5

# %%
pd.DataFrame(pop, index = [2000, 2001, 2002, 2003])
# Out:
#       Nevada  Ohio
# 2000     NaN   1.5
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN

# %%
frame3.index
# Out:
# Index([2001, 2002, 2000], dtype='int64')

# %%
frame3.values
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
pdata = {'Ohio': frame3['Ohio'][:-1],
        'Nevada': frame3['Nevada'][:2]}

# %%
pd.DataFrame(pdata)
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
# Set the DataFrame name, column name, and index name
frame3.name = 'population'
frame3.index.name = 'yaer'
frame3.columns.name = 'state'

# %%
frame3.name
# Out:
# 'population'

# %%
frame3.index.name
# Out:
# 'yaer'

# %%
frame3.columns.name
# Out:
# 'state'

# %%
frame3
# Out:
# state  Nevada  Ohio
# yaer
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
# As with Series, the values attribute returns the data conatined in the DataFrame as a two-dimensional ndarray
frame3.values
# Out:
# array([[2.4, 1.7],
#        [2.9, 3.6],
#        [nan, 1.5]])

# %%
# If the DataFrame's columns are different dtypes, the dtype of the values array will be chosen to accommodate all of the the columns
frame2.values
# Out:
# array([[2000, 'Ohio', 1.5, nan],
#        [2001, 'Ohio', 1.7, -1.2],
#        [2002, 'Ohio', 3.6, nan],
#        [2001, 'Nevada', 2.4, -1.5],
#        [2002, 'Nevada', 2.9, -1.7],
#        [2003, 'Nevada', 3.2, nan]], dtype=object)

# %% [markdown]
# # Index Objects
# 🎯Pandas's Index objects are responsible for holding the labels and other metadeta (like the axis name or names)

# %%
obj = pd.Series(range(3), index = ['a','b','c'])

# %%
index = obj.index

# %%
index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %%
# Index objects are immutable and thus can not be modified by the user
index[1] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[440], line 2
#       1 # Index objects are immutable and thus can not be modified by the user
# ----> 2 index[1] = 'd'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# Immutability makes it safer to share Index objects among data structure
labels = pd.Index(np.arange(3))

# %%
labels

# %%
obj2 = pd.Series([1.5, -2.5, 0], index = labels)

# %%
obj2

# %%
obj2.index is labels

# %%
idx = pd.Index(['a','b','c'])

# %%
s1 = pd.Series([1,2,3], index = idx)

# %%
s2 = pd.Series([4,5,6], index = idx)

# %%
# Both s1 and s share the same index object
s1.index is s2.index

# %%
# An Index also behaves like a fixed-size set
frame3

# %%
frame3.columns

# %%
# Check if a column exists in the columns
'Nevada' in frame3.columns

# %%
# Check if an index exists in the row labels/indices
2003 in frame3.index

# %%
# Unlike Python sets, a pandas Index can contain duplicate labels
dup_labels = pd.Index(['foo', 'foo', 'bar', 'bar'])

# %%
dup_labels

# %%
# Selection with duplicate labels will select all the occurrence of that label
s = pd.Series([1,2,3,4], index = dup_labels)

# %%
s.loc['foo']

# %% [markdown]
# # Essential Functionality

# %% [markdown]
# ### Reindexing
# 🎯An important method on pandas objects is reindex, which means to create a new object with the data confirmed to a new index

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index = ['d', 'b','a', 'c'])

# %%
obj

# %%
# Calling reindex on this Series rearranges the data according to the new index, introducing missing values if any values were not already present
obj2 = obj.reindex(['a','b','c','d','e'])

# %%
obj2

# %%
# We can use the method parameter to fill the missing values automatically
obj3 = pd.Series(['blue','purple','yellow'], index = [0,2,4])

# %%
obj3

# %%
# method parameter can only be used when the index is ordered - meaning the index must have a clear order so Pandas knows what 'forward/backward' means
obj3.reindex(range(6), method = 'ffill')

# %%
obj3.reindex(range(5), method = 'bfill')

# %%
# With DataFrame, reindex can alter the (row) index, columns, or both. When passed only a sequence, it reindexes the rows in the result
frame = pd.DataFrame(np.arange(9).reshape(3,3), index = ['a','c','d'], columns = ['Ohio','Texas','California'])

# %%
frame

# %%
frame2 = frame.reindex(['a','b','c','d'])

# %%
frame2

# %%
# The columns can be reindexed with the columns keyword
states = ['Texas', 'Utah', 'California']

# %%
frame.reindex(columns = states)

# %% [markdown]
# ### Dropping Entries from an Axis
# 🎯The drop method is used to drop entries. It will return a new object with theindicated value or values deleted from an axis

# %%
obj = pd.Series(np.arange(5.), index = ['a','b','c','d','e'])

# %%
obj

# %%
new_obj = obj.drop('c')

# %%
new_obj

# %%
obj.drop(['d','c'])

# %%
# With DataFrame, index values can be deleted from either axis
data = pd.DataFrame(np.arange(16).reshape(4,4), index = ['Ohio','Colorado','Utah','New York'], columns = ['one','two','three','four'])

# %%
data

# %%
# Calling drop with a sequence of labels will drop values from the row labels (axis 0)
data.drop(['Colorado','Ohio'])

# %%
data.drop(['Colorado','Ohio'], axis = 0)

# %%
# We acn drop values from columns by passing axis = 1 or axis = 'columns'
data.drop('two', axis = 1)

# %%
data.drop(['two','four'], axis = 'columns')

# %%
# Many functions, like drop, which modify the size or shape of a Series or DataFrame, can manipulate an object in-place without returning a new object
obj.drop('e', inplace = True)

# %%
obj

# %% [markdown]
# # Indexing, Selection, and Filtering

# %%
# Series ndexing works analogously to NumPy array indexing
obj = pd.Series(np.arange(4.), index = ['a','b','c','d'])

# %%
obj

# %%
print(obj['b'])

# %%
obj[['a','c','d']]

# %%
obj[obj > 2]

# %%
# Slicing with labels behaves differently than normal Python slicing in that the end-point is inclusive
obj['b':'c']

# %%
# Setting using these methods modifies the corresponding section of the series
obj['b':'c'] = 5

# %%
obj

# %%
# Indexing into a DataFrame is for retrieving one or more columns either with a single value or sequence
data = pd.DataFrame(np.arange(16).reshape(4,4), index = ['Ohio','Colorado','Utah','New York'], columns = ['one','two','three','four'])

# %%
data

# %%
data['one']

# %%
data[['one','three','four']]

# %%
# The row selection with slicing
data[:2]

# %%
# Indexing with a boolean data
data[data['three'] >5]

# %%
# Indexing with a boolean DataFrame
data < 5

# %%
data[data < 5] = 0

# %%
data

# %% [markdown]
# ### Selection with loc and iloc
# 🎯For DataFrame label-indexing on the rows, introduced special indexing operators loc and iloc. they enable to select a subset of the rows and columns from a DataFrame

# %%
data

# %%
data.loc[['Ohio']]

# %%
data.loc[['Colorado','New York']]

# %%
data.loc[['New York'], ['one']]

# %%
data.loc[['Ohio','Colorado','Utah'],['one','three','four']]

# %%
data.loc[['Ohio'],['one','three','four']]

# %%
data.iloc[0]

# %%
data.iloc[[0]]

# %%
data.iloc[[0,1,2],[1]]

# %%
data.iloc[[1,2,3],[0,1,2]]

# %%
data.iloc[:,2]

# %% [markdown]
# ### Integer Indexs

# %%
ser = pd.Series(np.arange(3.))

# %%
ser[-1]

# %%
ser2 = pd.Series(np.arange(3.), index = ['a','b','c'])

# %%
print(ser2[-1])

# %%
ser[:1]

# %%
ser.loc[:1]

# %%
ser.iloc[:1]

# %% [markdown]
# ### Arithmetic and Data Alignment

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index = ['a','b','c','d'])

# %%
s1

# %%
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index = ['a','c','e','f','g'])

# %%
s2

# %%
""" The internal data alignment introduces missing values in the label locations that do not overlap. Missing values will
then propagate in further arithmetic computations. """
# Adding these together yields:
s1 + s2

# %%
# In this case of DataFrame, alignment is performed on both the rows and the columns
df2 = pd.DataFrame(np.arange(9.).reshape((3,3)), columns = list('bcd'), index = ['Ohio','Texas','Colorado'])

# %%
df3 = pd.DataFrame(np.arange(12.).reshape((4,3)), columns = list('bde'), index = ['Utah','Ohio','Texas','Oregon'])

# %%
df2

# %%
df3

# %%
# Since the 'c' and 'e' columns are not found in both DataFrame objects, they appear as all missing in the result
df2 + df3

# %%
# If we add DataFrame objects with no column or row labels in common, the result will contain all nulls
df1 = pd.DataFrame({'A':[1,2]})

# %%
df2 = pd.DataFrame({'B':[3,4]})

# %%
df1

# %%
df2

# %%
df1 - df2

# %% [markdown]
# ### Arithmetic Methods with Fill Values

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3,4)), columns = list('abcd'))

# %%
df2 = pd.DataFrame(np.arange(20.).reshape((4,5)), columns = list('abcde'))

# %%
df1

# %%
df2.loc[1,'b'] = np.nan

# %%
df2

# %%
# Adding these together results in NA values in the locations that do not overlap
df1 + df2

# %%
# Using the add() method on df1, we passed df2 and an argument to fill_value
df1.add(df2, fill_value = 0)

# %%
df1.sub(df2, fill_value = 0)

# %%
df1.mul(df2, fill_value = 0)

# %%
df1.pow(df2, fill_value = 0)

# %%
# Relatedly, when reindexing a Series or DataFrame, you can also specify a different fill value
df1.reindex(columns = df2.columns, fill_value = 0)

# %% [markdown]
# ### Operations Between DataFrame and Series

# %%
""" As with NumPy arrays of different dimensions, arithmetic between DataFrame and Series is also deined - broadcasting """
arr = np.arange(12.).reshape((3,4))

# %%
arr

# %%
arr[0]

# %%
arr.shape

# %%
arr[0].shape

# %%
arr - arr[0]

# %%
# We can do the same with a DataFrame and a Series
frame = pd.DataFrame(np.arange(12.).reshape((4,3)), columns = list('bde'), index = ['Utah','Ohio','Texas','Oregon'])

# %%
series = pd.Series(frame.iloc[0])

# %%
frame

# %%
series

# %% [raw]
# frame.shape

# %%
series.shape

# %%
# By default DataFrame and Series matches the index of the Series on the DataFrame's columns, broadcasting down the rows
frame - series

# %%
# If an index value is not found in either the DataFrame's columns or the Series's index, the objects will be reindex to form the union
series2 = pd.Series(range(3), index = ['b','e','f'])

# %%
series2

# %%
frame + series2

# %%
# If we want to instead broadcast over the columns, matching on the rows, we have to use one of the arithmetic methods
series3 = frame['d']

# %%
series3

# %%
frame.sub(series3, axis = 'index')

# %% [markdown]
# ### Function Application and Mapping

# %%
# Numpy ufuncs (element-wise array methods) also work with pandas
frame = pd.DataFrame(np.random.randn(4,3), columns = list('bde'), index = ['Utah','Ohio','texas','Oregon'])

# %%
frame

# %%
np.abs(frame)

# %%
# Another frequent operation is applying a function on one-dimensional arrays to each column or row, DataFrame's apply method does exactly this
f = lambda x : x.max() - x.min()

# %%
frame.apply(f)

# %%
frame

# %%
# If we pass axis = 'columns' to apply, the function will be invoked once per row instead
frame.apply(f, axis = 'columns')

# %%
def f(x):
    return pd.Series([x.max(), x.min()], index = ['max', 'min'])

# %%
frame.apply(f)

# %%
format = lambda x : '%.2f' % x

# %%
frame['e'].map(format)

# %% [markdown]
# ### Sorting and Ranking

# %%
# Sorting a dataset by some criterion is another important built-in operation. To sort lexicographically by row or column index, use the sort_index method
obj = pd.Series(range(4), index = list('dabc'))

# %%
obj

# %%
# Returns a new, sorted object
obj.sort_index()

# %%
obj

# %%
# With a DataFrame, we can sort by index on either axis
frame = pd.DataFrame(np.arange(8).reshape((2,4)), index = ['three','one'], columns = list('dabc'))

# %%
# By default axis = 0 (vertically)
frame.sort_index()

# %%
# Along columns
frame.sort_index(axis = 'columns')

# %%
# Descending order
frame.sort_index(axis = 1, ascending = False)

# %%
# To sort a Series by its valus, use its sort_values method
obj = pd.Series([4,7,-3,2])

# %%
obj.sort_values()

# %%
# Any missing values are sorted to the end of the Series by default
obj = pd.Series([4, np.nan, 7, np.nan])

# %%
obj.sort_values()

# %%
# When sorting a DataFrame, we can use the data in one or more columns as the sort keys. To do so, pass one or more column names to the 'by' option of sort_values
frame = pd.DataFrame({'b':[4,7,-3,2],'a':[0,1,0,1]})

# %%
frame

# %%
frame.sort_values(by = 'b')

# %%
frame.sort_values(by = ['a','b'])

# %%
# Ranking assigns ranks from one through the number of valid data points in an array.By defualt rank breaks ties by assigning each group the mean rank
obj = pd.Series([7,-5,7,4,2,0,4])

# %%
obj.rank()

# %%
# Ranks can aslo be assigned according to the order in which they're observed in the data
obj.rank(method = 'first')

# %%
# Rank in descendding order
obj.rank(ascending = False, method = 'max') # Assing tie values the maximum rank in the group

# %%
# DataFrame can compute ranks over the rows or thee columns
frame = pd.DataFrame({'b':[4.3,7,-3,2],'a':[0,1,0,1],'c':[-2,5,8,-2.4]})

# %%
frame

# %%
frame.rank(axis = 'columns')

# %%
frame.rank()

# %%
obj.rank(method = 'max')

# %%
obj.rank(method = 'min')

# %%
obj.rank(method = 'dense')

# %% [markdown]
# ### Axis Indexes with Duplicate Labels

# %%
obj = pd.Series(range(5), index = list('aabbc'))

# %%
obj

# %%
# The indexs's is_unique property can tell whether its labels are unique or not
obj.index.is_unique

# %%
# Indexing a label with multiple entris returns a Series, while single entries return scalar value
obj['a']

# %%
obj['c']

# %%
df = pd.DataFrame(np.random.randn(4,3), index = list('aabb'))

# %%
df

# %%
df.loc['a']

# %%
df.loc['b']

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics
# 🔢Pandas objects are equiped with a set of common mathematical and statistical  methods. Most of these fall into the category of reductions or summary statistics, methods that extract a single value (like sum or mean) from a Series or a Series of values from rows or columns of a DataFrame

# %%
df = pd.DataFrame([[1.4, np.nan],[7.1, -4.5],[np.nan, np.nan], [0.75, -1.3]], index = list('abcd'), columns = ['one', 'two'])

# %%
df

# %%
df.shape

# %%
# Calling DataFrame's sum method returns a Series conatining columns sums
df.sum()

# %%
# Along the columns
df.sum(axis = 'columns')

# %%
df.mean()

# %%
df.mean(axis = 1)

# %%
# Disable skipna option
df.mean(skipna = False)

# %%
df.mean(axis = 1, skipna = False)

# %%
# Some methods, like idxmax and idxmin, return indirect statistics like the index value where the maximum or minimum values are attainde
df.idxmax()

# %%
df.idxmin()

# %%
# Cumulative sum
df.cumsum()

# %%
df.cumsum(axis = 1)

# %%
""" Another type of method is neither a reduction nor an accumulation. Descire is one such example, producing multiple summary statistics in one shot. """
df.describe()

# %%
# On non-numeric data, describe produces alternative summary statistics
obj = pd.Series(['a','a','b','c'] * 4)

# %%
obj

# %%
obj.describe()

# %% [markdown]
# ![{688C85A1-021E-4EBF-96AC-3D8877B03EE2}.png](attachment:ca2ada2e-d3f5-4a11-a589-245fbc5f2d4b.png)

# %%
df

# %%
# Count number of non-NaN values
df.count()

# %%
df.min()

# %%
df.max()

# %%
# Returns index position
obj.argmax()

# %%
obj.argmin()

# %%
# Compute sample quantile ranging from 0 to 1
df.quantile()

# %%
# Arithmetic median (50% quantile) of values
df.median()

# %%
# Product of all values
df.prod()

# %%
# Sample variance of values
df.var()

# %%
# Sample standard deviation of values
df.std()

# %%
# Sample skewness (third moment) of values
df.skew()

# %%
# Sample kurtosis (fourth moment) of values
df.kurt()

# %%
df.cummax()

# %%
df.cummin()

# %%
df.cumprod()

# %%
df.diff()

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(['c','a','d','a','a','b','b','c','c'])

# %%
uniques = obj.unique()

# %%
uniques

# %%
counts = obj.value_counts()

# %%
counts

# %%
mask = obj.isin(['b','c'])

# %%
mask

# %%
# isin perfoms a vectorized set membership check and can be useful in filtering a dataset down to a subset of values in a Series or column in a DataFrame
obj

# %%
obj.isin(['b','c'])

# %%
mask = obj.isin(['a','d'])

# %%
obj[mask]

# %%
# Related to isin is the Index.get_indexer() method, which gives you an index array from an array of possible non-distinct values into another array of distinct values
to_match = pd.Series(['c','a','b','b','c','a'])

# %%
to_match

# %%
unique_values = pd.Series(['c','b','a'])

# %%
# It tells where each element of to_match appears ininside the index(unique_values) 
pd.Index(unique_values).get_indexer(to_match)

# %%
# In some cases, you may want to compute a histogram on multiple related columns in a DataFrame
data = pd.DataFrame({'Qu1':[1,3,4,3,4],'Qu2':[2,3,1,2,3],'Qu3':[1,5,2,4,4]})

# %%
data

# %%
result = data.apply(pd.value_counts).fillna(0)

# %%
result

# %% [markdown]
# # Data Loading, Storage, and File Formats

# %% [markdown]
# ## Reading and Writing Data in Text Format
# 📋Pandas features a number of functions for reading tabular data as a DataFrame object.
#     🔹read_csv: load delimited data from a file, URL, or file-like object; use comma as defult
#     🔹read_table: load delimited data from a file, URL, or file-like object; use tab('\t') as default
#     🔹read_fwf: read data in fixed-width column format (i.e., no delimiters)
#     🔹read_clipboard: version of read_table that reads data from the     clipboard; useful for converting tables from web pages
#     🔹read_excel
#     🔹read_hdf
#     🔹read_html
#     🔹read_json
#     🔹read_msgpack
#     🔹raed_pickle
#     🔹read_sas
#     🔹raed_stata
#     🔹raed_sql
#     🔹read_feather

# %%
# %%writefile test.txt
# Hello from Jupyter!

# %%
# !type test.txt

# %%
# %%writefile example1.csv
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
# !type example1.csv

# %%
# Read the file (csv)
df = pd.read_csv('example1.csv')

# %%
df

# %%
# We could also have used read_table and specified the delimiter
pd.read_table('example1.csv', sep = ',')

# %%
# A file will not always have header row 
# %%writefile ex2.csv
1,2,3,4,hello
5,6,7,8,world
9,10,11,12,foo

# %%
# !type ex2.csv

# %%
# If we do not mention the header, it will consider the first row as a header row
df1 = pd.read_csv('ex2.csv')

# %%
df1

# %%
# Instead we can specify the header by ourselves; otherwise pandas will automatically assign default header or  column names with help of header argument
df2 = pd.read_csv('ex2.csv', header = None)

# %%
df2

# %%
# Set custom column names with help of 'names' argument
df3 = pd.read_csv('ex2.csv', names = ['a','b','c','d','message'])

# %%
df3

# %%
# If we want a column to be the index of the DataFrame, we can specify that using the 'index_col' argument
df4 = pd.read_csv('ex2.csv', names = ['a','b','c','d','message'], index_col = 'message')

# %%
df4

# %%
df4.index.name

# %%
# %%writefile ex3.csv
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16

# %%
# !type ex3.csv

# %%
# we can also set multiple columns as hierarchical index by passing a list of column
df5 = pd.read_csv('ex3.csv', names = ['key1','key2','value1','value2'])

# %%
df5

# %%
df6 = pd.read_csv('ex3.csv', names = ['key1','key2','value1','value2'], index_col = ['key1','key2'])

# %%
df6

# %%
# %%writefile ex4.txt
#                      A          B          C
#  aaa  -0.264438  -1.026059  -0.619500
#  ccc  -0.234565  -0.323453  -0.232454
#  ddd  -0.564454  -0.982468  1.1089887

# %%
# !type ex4.txt

# %%
# In some cases, a table might not have a fixed delimeter, using whitespace or some other pattern to separate fields
# In that cases, we can pass a regular expression as a delimiter for read_table
# The regular expression can be expressed by r\s+
df7 = pd.read_table('ex4.txt', sep = r'\s+')

# %%
df7

# %%
# Since the column name is less than the column, the first one would be treated as index
df7.loc[['aaa','ccc']]

# %%
# %%writefile ex6.csv
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computer, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
# !type ex6.csv

# %%
# If we want we can skip any rows with help of the 'skiprows' argument
result = pd.read_csv('ex6.csv', skiprows = [0,2,3])

# %%
result

# %%
# Missing data is usually either not present (empty string) or marked by some sentinel value (NA,NULL)
# %%writefile ex7.csv
something, a,b,c,d,message
one,1,2,3,4,NA
two,5,,7,8,world
three,9,10,11,12,foo

# %%
# !type ex7.csv
# Out:
# something, a,b,c,d,message
# one,1,2,3,4,NA
# two,5,,7,8,world
# three,9,10,11,12,foo

# %%
result = pd.read_csv('ex7.csv')

# %%
result
# Out:
#   something   a     b   c   d message
# 0       one   1   2.0   3   4     NaN
# 1       two   5   NaN   7   8   world
# 2     three   9  10.0  11  12     foo

# %%
# We can handle this null value with help of the isnull() function
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False   True  False  False    False
# 2      False  False  False  False  False    False

# %%
# We can also handle missing data during read the file
# The 'na_values' argument let us add our own customize null values indicator
handle_missing_values = pd.read_csv('ex7.csv', na_values = ['NULL'])

# %%
handle_missing_values
# Out:
#   something   a     b   c   d message
# 0       one   1   2.0   3   4     NaN
# 1       two   5   NaN   7   8   world
# 2     three   9  10.0  11  12     foo

# %%
sentinels = {'message':['foo', 'NA'], 'something':['two']}
result = pd.read_csv('ex7.csv', na_values = sentinels)

# %%
result
# Out:
#   something   a     b   c   d message
# 0       one   1   2.0   3   4     NaN
# 1       NaN   5   NaN   7   8   world
# 2     three   9  10.0  11  12     NaN

# %% [markdown]
# ### Reading Text Files in Pieces

# %%
# Before we look at a large file, we make the pandas display settings more compact
pd.options.display.max_rows = 10
pd.options.display.max_columns = 10

# %%
# Load the csv file
data = pd.read_csv('large_dataset.csv')

# %%
data.shape
# Out:
# (10000, 100)

# %%
data.describe()
# Out:
#               col_1         col_2         col_3         col_4         col_5  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.003066     -0.019374      0.007803     -0.002584     -0.006957
# std        0.996832      0.997986      0.999322      0.994109      1.006572
# min       -4.324064     -3.855302     -4.116778     -3.872791     -4.312963
# 25%       -0.673834     -0.691867     -0.672927     -0.668325     -0.686692
# 50%       -0.009166     -0.023667      0.004620     -0.008017      0.005648
# 75%        0.667000      0.665936      0.677233      0.670014      0.677124
# max        3.262381      3.790923      3.705894      3.913570      4.085309
#
#        ...        col_96        col_97        col_98        col_99  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...      0.000896      0.005818     -0.004236      0.012603
# std    ...      1.013223      0.986087      0.990394      1.001291
# min    ...     -3.916507     -3.998375     -3.392818     -3.806094
# 25%    ...     -0.677009     -0.651463     -0.670393     -0.660044
# 50%    ...     -0.000082      0.006971     -0.002568      0.012600
# 75%    ...      0.690860      0.676797      0.665221      0.688661
# max    ...      3.792899      3.946971      4.274556      3.710545
#
#             col_100
# count  10000.000000
# mean       0.005118
# std        0.987723
# min       -3.929995
# 25%       -0.651851
# 50%        0.005527
# 75%        0.683757
# max        3.652882
#
# [8 rows x 100 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 100 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   col_1    10000 non-null  float64
#  1   col_2    10000 non-null  float64
#  2   col_3    10000 non-null  float64
#  3   col_4    10000 non-null  float64
#  4   col_5    10000 non-null  float64
#  5   col_6    10000 non-null  float64
#  6   col_7    10000 non-null  float64
#  7   col_8    10000 non-null  float64
#  8   col_9    10000 non-null  float64
#  9   col_10   10000 non-null  float64
#  10  col_11   10000 non-null  float64
#  11  col_12   10000 non-null  float64
#  12  col_13   10000 non-null  float64
#  13  col_14   10000 non-null  float64
#  14  col_15   10000 non-null  float64
#  15  col_16   10000 non-null  float64
#  16  col_17   10000 non-null  float64
#  17  col_18   10000 non-null  float64
#  18  col_19   10000 non-null  float64
#  19  col_20   10000 non-null  float64
#  20  col_21   10000 non-null  float64
#  21  col_22   10000 non-null  float64
#  22  col_23   10000 non-null  float64
#  23  col_24   10000 non-null  float64
#  24  col_25   10000 non-null  float64
#  25  col_26   10000 non-null  float64
#  26  col_27   10000 non-null  float64
#  27  col_28   10000 non-null  float64
#  28  col_29   10000 non-null  float64
#  29  col_30   10000 non-null  float64
#  30  col_31   10000 non-null  float64
#  31  col_32   10000 non-null  float64
#  32  col_33   10000 non-null  float64
#  33  col_34   10000 non-null  float64
#  34  col_35   10000 non-null  float64
#  35  col_36   10000 non-null  float64
#  36  col_37   10000 non-null  float64
#  37  col_38   10000 non-null  float64
#  38  col_39   10000 non-null  float64
#  39  col_40   10000 non-null  float64
#  40  col_41   10000 non-null  float64
#  41  col_42   10000 non-null  float64
#  42  col_43   10000 non-null  float64
#  43  col_44   10000 non-null  float64
#  44  col_45   10000 non-null  float64
#  45  col_46   10000 non-null  float64
#  46  col_47   10000 non-null  float64
#  47  col_48   10000 non-null  float64
#  48  col_49   10000 non-null  float64
#  49  col_50   10000 non-null  float64
#  50  col_51   10000 non-null  float64
#  51  col_52   10000 non-null  float64
#  52  col_53   10000 non-null  float64
#  53  col_54   10000 non-null  float64
#  54  col_55   10000 non-null  float64
#  55  col_56   10000 non-null  float64
#  56  col_57   10000 non-null  float64
#  57  col_58   10000 non-null  float64
#  58  col_59   10000 non-null  float64
#  59  col_60   10000 non-null  float64
#  60  col_61   10000 non-null  float64
#  61  col_62   10000 non-null  float64
#  62  col_63   10000 non-null  float64
#  63  col_64   10000 non-null  float64
#  64  col_65   10000 non-null  float64
#  65  col_66   10000 non-null  float64
#  66  col_67   10000 non-null  float64
#  67  col_68   10000 non-null  float64
#  68  col_69   10000 non-null  float64
#  69  col_70   10000 non-null  float64
#  70  col_71   10000 non-null  float64
#  71  col_72   10000 non-null  float64
#  72  col_73   10000 non-null  float64
#  73  col_74   10000 non-null  float64
#  74  col_75   10000 non-null  float64
#  75  col_76   10000 non-null  float64
#  76  col_77   10000 non-null  float64
#  77  col_78   10000 non-null  float64
#  78  col_79   10000 non-null  float64
#  79  col_80   10000 non-null  float64
#  80  col_81   10000 non-null  float64
#  81  col_82   10000 non-null  float64
#  82  col_83   10000 non-null  float64
#  83  col_84   10000 non-null  float64
#  84  col_85   10000 non-null  float64
#  85  col_86   10000 non-null  float64
#  86  col_87   10000 non-null  float64
#  87  col_88   10000 non-null  float64
#  88  col_89   10000 non-null  float64
#  89  col_90   10000 non-null  float64
#  90  col_91   10000 non-null  float64
#  91  col_92   10000 non-null  float64
#  92  col_93   10000 non-null  float64
#  93  col_94   10000 non-null  float64
#  94  col_95   10000 non-null  float64
#  95  col_96   10000 non-null  float64
#  96  col_97   10000 non-null  float64
#  97  col_98   10000 non-null  float64
#  98  col_99   10000 non-null  float64
#  99  col_100  10000 non-null  float64
# dtypes: float64(100)
# memory usage: 7.6 MB

# %%
# We can specify how many rows we want during reading the file
pd.read_csv('large_dataset.csv', nrows = 7)
# Out:
#       col_1     col_2     col_3     col_4     col_5  ...    col_96    col_97  \
# 0 -0.263980 -0.846611  1.453268  1.251567  2.398590  ... -0.366923  1.339828
# 1  1.258475  1.642030 -0.401637 -0.189602 -1.045877  ...  0.292131 -0.163091
# 2 -0.411287 -0.966434 -0.972459  0.170160 -0.658988  ... -0.494592  0.398968
# 3  1.930533 -0.268566 -0.142144  1.215926  0.589795  ...  0.782485 -0.063909
# 4 -0.693826 -0.224357 -0.907838 -0.548491  0.524646  ... -1.191671  0.045964
# 5  0.505134  1.579838  0.524227 -2.020217  0.129764  ... -1.216672  0.963707
# 6 -0.293944 -0.782067 -2.813539  0.256526 -1.034974  ... -1.051752  0.488756
#
#      col_98    col_99   col_100
# 0  0.012093 -0.491650  0.432837
# 1  0.240092  0.954998  1.271104
# 2  1.262306 -0.268114 -0.328491
# 3  0.062339  0.209707 -1.061527
# 4  0.013986  0.236547  2.780695
# 5 -1.444545 -0.741600  1.547811
# 6  1.074602  0.235672  1.524139
#
# [7 rows x 100 columns]

# %%
# using head method
data.head()
# Out:
#       col_1     col_2     col_3     col_4     col_5  ...    col_96    col_97  \
# 0 -0.263980 -0.846611  1.453268  1.251567  2.398590  ... -0.366923  1.339828
# 1  1.258475  1.642030 -0.401637 -0.189602 -1.045877  ...  0.292131 -0.163091
# 2 -0.411287 -0.966434 -0.972459  0.170160 -0.658988  ... -0.494592  0.398968
# 3  1.930533 -0.268566 -0.142144  1.215926  0.589795  ...  0.782485 -0.063909
# 4 -0.693826 -0.224357 -0.907838 -0.548491  0.524646  ... -1.191671  0.045964
#
#      col_98    col_99   col_100
# 0  0.012093 -0.491650  0.432837
# 1  0.240092  0.954998  1.271104
# 2  1.262306 -0.268114 -0.328491
# 3  0.062339  0.209707 -1.061527
# 4  0.013986  0.236547  2.780695
#
# [5 rows x 100 columns]

# %%
# If the file size is larger, we can use chunksize as number of rows to read data in pieces
chunker = pd.read_csv('large_dataset.csv', chunksize = 100)

# %%
chunker

# %%
for piece in chunker:
    print(type(piece))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
chunker = pd.read_csv('large_dataset.csv', chunksize = 500)
series = pd.Series([])
for piece in chunker:
    series = series.add(piece['col_3'].value_counts(), fill_value = 0)

# %%
series
# Out:
# col_3
# -4.116778    1.0
# -3.659848    1.0
# -3.602267    1.0
# -3.474493    1.0
# -3.418491    1.0
#             ...
#  3.145004    1.0
#  3.161427    1.0
#  3.243044    1.0
#  3.478796    1.0
#  3.705894    1.0
# Length: 10000, dtype: object
